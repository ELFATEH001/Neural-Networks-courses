# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        # conv layers
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)

        # affine ops
        self.fc1 = nn.Linear(16 *5 *5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self,input):
        c1 = F.relu(slef.conv1(input))
        s2 = F.max_pool2d(c1, (2, 2))
        c3 = F.relu(self.conv2(s2))
        s4 = F.max_pool2d(c3, 2)
        s4 = torch.flatten(s4, 1)
        f5 = F.relu(self.fc1(s4))
        f6 = F.relu(self.fc2(s5))

        output = self.fc3(f6)
        return output

net = Net()
print(net)
# Out:
# Net(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %% [markdown]
# ## torch for RL

# %%
import torch 
import torch.nn as nn
import torch.optim as optim

# %%
class SimpleMLP(nn.Module):
    def __init__(self,input_size, hidden_size, output_size):
        super(SimpleMLP, self).__init__()
        self.fc1 = nn.Linear(input_size,hidden_size)
        self.fc2 = nn.Linear(hidden_size,hidden_size)
        self.fc3 = nn.Linear(hidden_size,output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net = SimpleMLP(4,64,2)
print(net)
# Out:
# SimpleMLP(
#   (fc1): Linear(in_features=4, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
# test net
test = torch.rand((1, 4))
label = torch.rand((1, 2))
result = net(test)
print("input is {}, ouput is {}".format(test, result))
# Out:
# input is tensor([[0.5605, 0.8809, 0.4359, 0.7195]]), ouput is tensor([[-0.0982, -0.1172]], grad_fn=<AddmmBackward0>)

# %%
# loss and optimization
loss = result - label
optim = optim.SGD(net.parameters(), lr=.1)
optim.zero_grad()
loss.backward
optim.step
# Out:
# <bound method SGD.step of SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.1
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )>
